# %% [markdown]
# # Funding rates analysis across different exchanges

# %% [markdown]
# ### Merge all BTC pairs and graph the funding rates

# %%
# Import needed libraries
import pandas as pd
import plotly.graph_objects as go
from glob import glob
import numpy as np
import plotly.express as px

# %%
# List all exchanges
exchanges = ["Binance", "BitMex", "Bybit", "Deribit", "Huobi", "OKX"]

# %%
# Step 1: Read and process data
def read_and_resample_csv(file_path, resample_period='12H'):
    df = pd.read_csv(file_path, parse_dates=['date'])
    df = df[["date", "funding_rate"]]
    df.set_index('date', inplace=True)
    df = df.tz_localize(None)
    df_resampled = df.resample(resample_period).mean()
    return df_resampled

# %%
exchange_data = {}
for exchange in exchanges:
    coin_exchange = "BTC_" + exchange
    exchange_data[coin_exchange] = read_and_resample_csv("data/" + coin_exchange + ".csv")

# %%
# Step 2: Merge data
merged_df = pd.concat(exchange_data, axis=1)
merged_df.columns = [f"{name}_{col}" for name in exchange_data.keys() for col in exchange_data[name].columns]
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3420 entries, 2019-09-10 00:00:00 to 2024-05-15 12:00:00
# Freq: 12H
# Data columns (total 6 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   BTC_Binance_funding_rate  3419 non-null   float64
#  1   BTC_BitMex_funding_rate   1836 non-null   float64
#  2   BTC_Bybit_funding_rate    3024 non-null   float64
#  3   BTC_Deribit_funding_rate  2322 non-null   float64
#  4   BTC_Huobi_funding_rate    2002 non-null   float64
#  5   BTC_OKX_funding_rate      2002 non-null   float64
# dtypes: float64(6)
# memory usage: 187.0 KB

# %%
merged_df.head()
# Out:
#                      BTC_Binance_funding_rate  BTC_BitMex_funding_rate  \
# date
# 2019-09-10 00:00:00                    0.0001                      NaN
# 2019-09-10 12:00:00                    0.0001                      NaN
# 2019-09-11 00:00:00                    0.0001                      NaN
# 2019-09-11 12:00:00                    0.0001                      NaN
# 2019-09-12 00:00:00                    0.0001                      NaN
#
#                      BTC_Bybit_funding_rate  BTC_Deribit_funding_rate  \
# date
# 2019-09-10 00:00:00                     NaN                       NaN
# 2019-09-10 12:00:00                     NaN                       NaN
# 2019-09-11 00:00:00                     NaN                       NaN
# 2019-09-11 12:00:00                     NaN                       NaN
# 2019-09-12 00:00:00                     NaN                       NaN
#
#                      BTC_Huobi_funding_rate  BTC_OKX_funding_rate
# date
# 2019-09-10 00:00:00                     NaN                   NaN
# 2019-09-10 12:00:00                     NaN                   NaN
# 2019-09-11 00:00:00                     NaN                   NaN
# 2019-09-11 12:00:00                     NaN                   NaN
# 2019-09-12 00:00:00                     NaN                   NaN

# %%
# Scale back some of the exchanges by 100 (to convert from percentage to point terms)
merged_df["BTC_Huobi_funding_rate"] = merged_df["BTC_Huobi_funding_rate"] / 100
merged_df["BTC_BitMex_funding_rate"] = merged_df["BTC_BitMex_funding_rate"] / 100
merged_df["BTC_OKX_funding_rate"] = merged_df["BTC_OKX_funding_rate"] / 100

# %%
# Step 3: Create an interactive plot
fig = go.Figure()

for exchange in exchange_data.keys():
    fig.add_trace(go.Scatter(
        x=merged_df.index,
        y=merged_df[f"{exchange}_funding_rate"],
        mode='lines',
        name=exchange
    ))

fig.update_layout(
    title='BTC Funding Rates Across Exchanges',
    xaxis_title='Date',
    yaxis_title='Funding Rate',
    xaxis=dict(
        tickformat="%b, %Y",  # Display date in Month Day, Year format
        dtick="M1", # Set tick interval to 1 month; for weekly, use "D7"
        tickfont=dict(size=8)
    ),
    yaxis=dict(
        tickformat=".4f"
    ),
)

fig.show()
# Out:
# <div>                            <div id="5b656834-1676-4be9-bac0-6b84c0d227d3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5b656834-1676-4be9-bac0-6b84c0d227d3")) {                    Plotly.newPlot(                        "5b656834-1676-4be9-bac0-6b84c0d227d3",                        [{"mode":"lines","name":"BTC_Binance","x":["2019-09-10T00:00:00","2019-09-10T12:00:00","2019-09-11T00:00:00","2019-09-11T12:00:00","2019-09-12T00:00:00","2019-09-12T12:00:00","2019-09-13T00:00:00","2019-09-13T12:00:00","2019-09-14T00:00:00","2019-09-14T12:00:00","2019-09-15T00:00:00","2019-09-15T12:00:00","2019-09-16T00:00:00","2019-09-16T12:00:00","2019-09-17T00:00:00","2019-09-17T12:00:00","2019-09-18T00:00:00","2019-09-18T12:00:00","2019-09-19T00:00:00","2019-09-19T12:00:00","2019-09-20T00:00:00","2019-09-20T12:00:00","2019-09-21T00:00:00","2019-09-21T12:00:00","2019-09-22T00:00:00","2019-09-22T12:00:00","2019-09-23T00:00:00","2019-09-23T12:00:00","2019-09-24T00:00:00","2019-09-24T12:00:00","2019-09-25T00:00:00","2019-09-25T12:00:00","2019-09-26T00:00:00","2019-09-26T12:00:00","2019-09-27T00:00:00","2019-09-27T12:00:00","2019-09-28T00:00:00","2019-09-28T12:00:00","2019-09-29T00:00:00","2019-09-29T12:00:00","2019-09-30T00:00:00","2019-09-30T12:00:00","2019-10-01T00:00:00","2019-10-01T12:00:00","2019-10-02T00:00:00","2019-10-02T12:00:00","2019-10-03T00:00:00","2019-10-03T12:00:00","2019-10-04T00:00:00","2019-10-04T12:00:00","2019-10-05T00:00:00","2019-10-05T12:00:00","2019-10-06T00:00:00","2019-10-06T12:00:00","2019-10-07T00:00:00","2019-10-07T12:00:00","2019-10-08T00:00:00","2019-10-08T12:00:00","2019-10-09T00:00:00","2019-10-09T12:00:00","2019-10-10T00:00:00","2019-10-10T12:00:00","2019-10-11T00:00:00","2019-10-11T12:00:00","2019-10-12T00:00:00","2019-10-12T12:00:00","2019-10-13T00:00:00","2019-10-13T12:00:00","2019-10-14T00:00:00","2019-10-14T12:00:00","2019-10-15T00:00:00","2019-10-15T12:00:00","2019-10-16T00:00:00","2019-10-16T12:00:00","2019-10-17T00:00:00","2019-10-17T12:00:00","2019-10-18T00:00:00","2019-10-18T12:00:00","2019-10-19T00:00:00","2019-10-19T12:00:00","2019-10-20T00:00:00","2019-10-20T12:00:00","2019-10-21T00:00:00","2019-10-21T12:00:00","2019-10-22T00:00:00","2019-10-22T12:00:00","2019-10-23T00:00:00","2019-10-23T12:00:00","2019-10-24T00:00:00","2019-10-24T12:00:00","2019-10-25T00:00:00","2019-10-25T12:00:00","2019-10-26T00:00:00","2019-10-26T12:00:00","2019-10-27T00:00:00","2019-10-27T12:00:00","2019-10-28T00:00:00","2019-10-28T12:00:00","2019-10-29T00:00:00","2019-10-29T12:00:00","2019-10-30T00:00:00","2019-10-30T12:00:00","2019-10-31T00:00:00","2019-10-31T12:00:00","2019-11-01T00:00:00","2019-11-01T12:00:00","2019-11-02T00:00:00","2019-11-02T12:00:00","2019-11-03T00:00:00","2019-11-03T12:00:00","2019-11-04T00:00:00","2019-11-04T12:00:00","2019-11-05T00:00:00","2019-11-05T12:00:00","2019-11-06T00:00:00","2019-11-06T12:00:00","2019-11-07T00:00:00","2019-11-07T12:00:00","2019-11-08T00:00:00","2019-11-08T12:00:00","2019-11-09T00:00:00","2019-11-09T12:00:00","2019-11-10T00:00:00","2019-11-10T12:00:00","2019-11-11T00:00:00","2019-11-11T12:00:00","2019-11-12T00:00:00","2019-11-12T12:00:00","2019-11-13T00:00:00","2019-11-13T12:00:00","2019-11-14T00:00:00","2019-11-14T12:00:00","2019-11-15T00:00:00","2019-11-15T12:00:00","2019-11-16T00:00:00","2019-11-16T12:00:00","2019-11-17T00:00:00","2019-11-17T12:00:00","2019-11-18T00:00:00","2019-11-18T12:00:00","2019-11-19T00:00:00","2019-11-19T12:00:00","2019-11-20T00:00:00","2019-11-20T12:00:00","2019-11-21T00:00:00","2019-11-21T12:00:00","2019-11-22T00:00:00","2019-11-22T12:00:00","2019-11-23T00:00:00","2019-11-23T12:00:00","2019-11-24T00:00:00","2019-11-24T12:00:00","2019-11-25T00:00:00","2019-11-25T12:00:00","2019-11-26T00:00:00","2019-11-26T12:00 ...

# %%
# Step 4: Save aggregated data into one file
merged_df.to_csv("data/BTC_merged.csv")

# %% [markdown]
# ### Merge all ETH pairs and graph the funding rates

# %%
# Repeat the same process for ETH
exchange_data = {}
for exchange in exchanges:
    coin_exchange = "ETH_" + exchange
    exchange_data[coin_exchange] = read_and_resample_csv("data/" + coin_exchange + ".csv")

# %%
# Step 2: Merge data
merged_df_eth = pd.concat(exchange_data, axis=1)
merged_df_eth.columns = [f"{name}_{col}" for name in exchange_data.keys() for col in exchange_data[name].columns]
merged_df_eth.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3264 entries, 2019-11-27 00:00:00 to 2024-05-15 12:00:00
# Freq: 12H
# Data columns (total 6 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ETH_Binance_funding_rate  3263 non-null   float64
#  1   ETH_BitMex_funding_rate   1836 non-null   float64
#  2   ETH_Bybit_funding_rate    2605 non-null   float64
#  3   ETH_Deribit_funding_rate  2175 non-null   float64
#  4   ETH_Huobi_funding_rate    2002 non-null   float64
#  5   ETH_OKX_funding_rate      2002 non-null   float64
# dtypes: float64(6)
# memory usage: 178.5 KB

# %%
# Scale back some of the exchanges by 100 (to convert from percentage to point terms)
merged_df_eth["ETH_Huobi_funding_rate"] = merged_df_eth["ETH_Huobi_funding_rate"] / 100
merged_df_eth["ETH_BitMex_funding_rate"] = merged_df_eth["ETH_BitMex_funding_rate"] / 100
merged_df_eth["ETH_OKX_funding_rate"] = merged_df_eth["ETH_OKX_funding_rate"] / 100

# %%
# Step 3: Create an interactive plot
fig = go.Figure()

for exchange in exchange_data.keys():
    fig.add_trace(go.Scatter(
        x=merged_df_eth.index,
        y=merged_df_eth[f"{exchange}_funding_rate"],
        mode='lines',
        name=exchange
    ))

fig.update_layout(
    title='ETH Funding Rates Across Exchanges',
    xaxis_title='Date',
    yaxis_title='Funding Rate',
    xaxis=dict(
        tickformat="%b, %Y",  # Display date in Month Day, Year format
        dtick="M1", # Set tick interval to 1 month; for weekly, use "D7"
        tickfont=dict(size=8)
    ),
    yaxis=dict(
        tickformat=".4f"
    ),
)

fig.show()
# Out:
# <div>                            <div id="f13e4f12-8e10-4f43-a487-ae3df12d4ea8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f13e4f12-8e10-4f43-a487-ae3df12d4ea8")) {                    Plotly.newPlot(                        "f13e4f12-8e10-4f43-a487-ae3df12d4ea8",                        [{"mode":"lines","name":"ETH_Binance","x":["2019-11-27T00:00:00","2019-11-27T12:00:00","2019-11-28T00:00:00","2019-11-28T12:00:00","2019-11-29T00:00:00","2019-11-29T12:00:00","2019-11-30T00:00:00","2019-11-30T12:00:00","2019-12-01T00:00:00","2019-12-01T12:00:00","2019-12-02T00:00:00","2019-12-02T12:00:00","2019-12-03T00:00:00","2019-12-03T12:00:00","2019-12-04T00:00:00","2019-12-04T12:00:00","2019-12-05T00:00:00","2019-12-05T12:00:00","2019-12-06T00:00:00","2019-12-06T12:00:00","2019-12-07T00:00:00","2019-12-07T12:00:00","2019-12-08T00:00:00","2019-12-08T12:00:00","2019-12-09T00:00:00","2019-12-09T12:00:00","2019-12-10T00:00:00","2019-12-10T12:00:00","2019-12-11T00:00:00","2019-12-11T12:00:00","2019-12-12T00:00:00","2019-12-12T12:00:00","2019-12-13T00:00:00","2019-12-13T12:00:00","2019-12-14T00:00:00","2019-12-14T12:00:00","2019-12-15T00:00:00","2019-12-15T12:00:00","2019-12-16T00:00:00","2019-12-16T12:00:00","2019-12-17T00:00:00","2019-12-17T12:00:00","2019-12-18T00:00:00","2019-12-18T12:00:00","2019-12-19T00:00:00","2019-12-19T12:00:00","2019-12-20T00:00:00","2019-12-20T12:00:00","2019-12-21T00:00:00","2019-12-21T12:00:00","2019-12-22T00:00:00","2019-12-22T12:00:00","2019-12-23T00:00:00","2019-12-23T12:00:00","2019-12-24T00:00:00","2019-12-24T12:00:00","2019-12-25T00:00:00","2019-12-25T12:00:00","2019-12-26T00:00:00","2019-12-26T12:00:00","2019-12-27T00:00:00","2019-12-27T12:00:00","2019-12-28T00:00:00","2019-12-28T12:00:00","2019-12-29T00:00:00","2019-12-29T12:00:00","2019-12-30T00:00:00","2019-12-30T12:00:00","2019-12-31T00:00:00","2019-12-31T12:00:00","2020-01-01T00:00:00","2020-01-01T12:00:00","2020-01-02T00:00:00","2020-01-02T12:00:00","2020-01-03T00:00:00","2020-01-03T12:00:00","2020-01-04T00:00:00","2020-01-04T12:00:00","2020-01-05T00:00:00","2020-01-05T12:00:00","2020-01-06T00:00:00","2020-01-06T12:00:00","2020-01-07T00:00:00","2020-01-07T12:00:00","2020-01-08T00:00:00","2020-01-08T12:00:00","2020-01-09T00:00:00","2020-01-09T12:00:00","2020-01-10T00:00:00","2020-01-10T12:00:00","2020-01-11T00:00:00","2020-01-11T12:00:00","2020-01-12T00:00:00","2020-01-12T12:00:00","2020-01-13T00:00:00","2020-01-13T12:00:00","2020-01-14T00:00:00","2020-01-14T12:00:00","2020-01-15T00:00:00","2020-01-15T12:00:00","2020-01-16T00:00:00","2020-01-16T12:00:00","2020-01-17T00:00:00","2020-01-17T12:00:00","2020-01-18T00:00:00","2020-01-18T12:00:00","2020-01-19T00:00:00","2020-01-19T12:00:00","2020-01-20T00:00:00","2020-01-20T12:00:00","2020-01-21T00:00:00","2020-01-21T12:00:00","2020-01-22T00:00:00","2020-01-22T12:00:00","2020-01-23T00:00:00","2020-01-23T12:00:00","2020-01-24T00:00:00","2020-01-24T12:00:00","2020-01-25T00:00:00","2020-01-25T12:00:00","2020-01-26T00:00:00","2020-01-26T12:00:00","2020-01-27T00:00:00","2020-01-27T12:00:00","2020-01-28T00:00:00","2020-01-28T12:00:00","2020-01-29T00:00:00","2020-01-29T12:00:00","2020-01-30T00:00:00","2020-01-30T12:00:00","2020-01-31T00:00:00","2020-01-31T12:00:00","2020-02-01T00:00:00","2020-02-01T12:00:00","2020-02-02T00:00:00","2020-02-02T12:00:00","2020-02-03T00:00:00","2020-02-03T12:00:00","2020-02-04T00:00:00","2020-02-04T12:00:00","2020-02-05T00:00:00","2020-02-05T12:00:00","2020-02-06T00:00:00","2020-02-06T12:00:00","2020-02-07T00:00:00","2020-02-07T12:00:00","2020-02-08T00:00:00","2020-02-08T12:00:00","2020-02-09T00:00:00","2020-02-09T12:00:00","2020-02-10T00:00:00","2020-02-10T12:00:00","2020-02-11T00:00:00","2020-02-11T12:00:00","2020-02-12T00:00:00","2020-02-12T12:00 ...

# %%
# Step 4: Save aggregated data into one file
merged_df_eth.to_csv("data/ETH_merged.csv")

# %% [markdown]
# ### Analyze and compare funding rate trends

# %%
merged_df.describe()
# Out:
#        BTC_Binance_funding_rate  BTC_BitMex_funding_rate  \
# count               3419.000000              1836.000000
# mean                   0.000136                 0.008135
# std                    0.000239                 0.016644
# min                   -0.001580                -0.291800
# 25%                    0.000043                 0.006775
# 50%                    0.000100                 0.010000
# 75%                    0.000100                 0.010000
# max                    0.002490                 0.098900
#
#        BTC_Bybit_funding_rate  BTC_Deribit_funding_rate  \
# count             3024.000000               2322.000000
# mean                 0.000155                  0.000077
# std                  0.000362                  0.000198
# min                 -0.002857                 -0.001814
# 25%                  0.000055                 -0.000002
# 50%                  0.000100                  0.000020
# 75%                  0.000100                  0.000116
# max                  0.003096                  0.001759
#
#        BTC_Huobi_funding_rate  BTC_OKX_funding_rate  ETH_Binance_funding_rate  \
# count             2002.000000           2002.000000               3263.000000
# mean                 0.008448              0.006308                  0.000169
# std                  0.012145              0.014538                  0.000318
# min                 -0.058568             -0.096016                 -0.003563
# 25%                  0.005201             -0.001620                  0.000052
# 50%                  0.010000              0.004340                  0.000100
# 75%                  0.010000              0.011215                  0.000100
# max                  0.107779              0.130932                  0.003353
#
#        ETH_BitMex_funding_rate  ETH_Bybit_funding_rate  \
# count              1836.000000             2605.000000
# mean                  0.006549                0.000180
# std                   0.025786                0.000388
# min                  -0.600300               -0.003017
# 25%                   0.006775                0.000057
# 50%                   0.010000                0.000100
# 75%                   0.010000                0.000100
# max                   0.129700                0.003750
#
#        ETH_Deribit_funding_rate  ETH_Huobi_funding_rate  ETH_OKX_funding_rate
# count               2175.000000             2002.000000           2002.000000
# mean                   0.000072                0.007981              0.004349
# std                    0.000281                0.015648              0.019744
# min                   -0.003154               -0.150030             -0.276952
# 25%                   -0.000010                0.002628             -0.004566
# 50%                    0.000015                0.010000              0.003674
# 75%                    0.000103                0.010000              0.012403
# max                    0.002296                0.146693              0.147424

# %%
merged_df_eth.describe()
# Out:
#        ETH_Binance_funding_rate  ETH_BitMex_funding_rate  \
# count               3263.000000              1836.000000
# mean                   0.000169                 0.000065
# std                    0.000318                 0.000258
# min                   -0.003563                -0.006003
# 25%                    0.000052                 0.000068
# 50%                    0.000100                 0.000100
# 75%                    0.000100                 0.000100
# max                    0.003353                 0.001297
#
#        ETH_Bybit_funding_rate  ETH_Deribit_funding_rate  \
# count             2605.000000               2175.000000
# mean                 0.000180                  0.000072
# std                  0.000388                  0.000281
# min                 -0.003017                 -0.003154
# 25%                  0.000057                 -0.000010
# 50%                  0.000100                  0.000015
# 75%                  0.000100                  0.000103
# max                  0.003750                  0.002296
#
#        ETH_Huobi_funding_rate  ETH_OKX_funding_rate
# count             2002.000000           2002.000000
# mean                 0.000080              0.000043
# std                  0.000156              0.000197
# min                 -0.001500             -0.002770
# 25%                  0.000026             -0.000046
# 50%                  0.000100              0.000037
# 75%                  0.000100              0.000124
# max                  0.001467              0.001474

# %%
# Calculate summary statistics
summary = merged_df.describe().transpose()
summary['exchange'] = summary.index
summary = summary[['exchange', 'mean', 'min', 'max']]

# Annualized funding rates
summary['mean'] = summary['mean'] * 3 * 365

fig = go.Figure()

fig.add_trace(go.Bar(
    x=summary['exchange'],
    y=summary['mean'],
    name="Mean",
    text=summary['mean'] * 100,  # Multiply by 100 to convert to percentage
    texttemplate='%{text:.2f}%',  # Format as percentage with two decimal places
    textposition='inside'  # Position text outside the bars
))
    
fig.update_layout(
    title='Annualized BTC Funding Rates Across Exchanges',
    xaxis_title='Exchange',
    yaxis_title='Annualized Mean Funding Rate',
    barmode='group',  # Display bars side-by-side
    yaxis=dict(
        tickformat=".5f"
    ),
)

fig.show()
# Out:
# <div>                            <div id="1e625b4c-54c1-4ea1-bffc-cca05758cca0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1e625b4c-54c1-4ea1-bffc-cca05758cca0")) {                    Plotly.newPlot(                        "1e625b4c-54c1-4ea1-bffc-cca05758cca0",                        [{"name":"Mean","text":[14.915322368382567,8.907789215686275,16.953713725198412,8.465121662024398,9.250972956527953,6.907166901330634],"textposition":"inside","texttemplate":"%{text:.2f}%","x":["BTC_Binance_funding_rate","BTC_BitMex_funding_rate","BTC_Bybit_funding_rate","BTC_Deribit_funding_rate","BTC_Huobi_funding_rate","BTC_OKX_funding_rate"],"y":[0.14915322368382566,0.08907789215686275,0.1695371372519841,0.08465121662024398,0.09250972956527953,0.06907166901330634],"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"marker":{"line":{"color":"#283442"}},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type" ...

# %%
# Calculate summary statistics
summary = merged_df_eth.describe().transpose()
summary['exchange'] = summary.index
summary = summary[['exchange', 'mean', 'min', 'max']]

# Annualized funding rates
summary['mean'] = summary['mean'] * 3 * 365

fig = go.Figure()

fig.add_trace(go.Bar(
    x=summary['exchange'],
    y=summary['mean'],
    name="Mean",
    text=summary['mean'] * 100,  # Multiply by 100 to convert to percentage
    texttemplate='%{text:.2f}%',  # Format as percentage with two decimal places
    textposition='inside'  # Position text outside the bars
))

fig.update_layout(
    title='Annualized ETH Funding Rates Across Exchanges',
    xaxis_title='Exchange',
    yaxis_title='Annualized Mean Funding Rate',
    barmode='group',  # Display bars side-by-side
    yaxis=dict(
        tickformat=".2f"
    ),
)

fig.show()
# Out:
# <div>                            <div id="3b8756ff-677d-4883-b548-e1d16ce6f1d3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3b8756ff-677d-4883-b548-e1d16ce6f1d3")) {                    Plotly.newPlot(                        "3b8756ff-677d-4883-b548-e1d16ce6f1d3",                        [{"name":"Mean","text":[18.465559737971194,7.170937908496732,19.6557815268714,7.839385127555916,8.73935014651056,4.762295037710105],"textposition":"inside","texttemplate":"%{text:.2f}%","x":["ETH_Binance_funding_rate","ETH_BitMex_funding_rate","ETH_Bybit_funding_rate","ETH_Deribit_funding_rate","ETH_Huobi_funding_rate","ETH_OKX_funding_rate"],"y":[0.18465559737971193,0.07170937908496733,0.19655781526871402,0.07839385127555916,0.0873935014651056,0.047622950377101056],"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"marker":{"line":{"color":"#283442"}},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":" ...

# %% [markdown]
# ### Number of intervals with negative/positive funding rates

# %%
# Count positive and negative intervals
summary_counts = {}

for column in merged_df.columns:
    exchange_name = column
    positive_count = (merged_df[column] >= 0).sum()
    negative_count = (merged_df[column] < 0).sum()
    pos_neg_ratio = positive_count / (positive_count + negative_count)
    summary_counts[exchange_name] = {'positive': positive_count, 'negative': negative_count, 'ratio': pos_neg_ratio}

# Convert summary_counts to DataFrame for better visualization
summary_counts_df = pd.DataFrame.from_dict(summary_counts, orient='index')
summary_counts_df.head(20)
# Out:
#                           positive  negative     ratio
# BTC_Binance_funding_rate      2999       420  0.877157
# BTC_BitMex_funding_rate       1569       267  0.854575
# BTC_Bybit_funding_rate        2621       403  0.866733
# BTC_Deribit_funding_rate      1670       652  0.719208
# BTC_Huobi_funding_rate        1709       293  0.853646
# BTC_OKX_funding_rate          1381       621  0.689810

# %%
# Count positive and negative intervals
summary_counts_eth = {}

for column in merged_df_eth.columns:
    exchange_name = column
    positive_count = (merged_df_eth[column] >= 0).sum()
    negative_count = (merged_df_eth[column] < 0).sum()
    pos_neg_ratio = positive_count / (positive_count + negative_count)
    summary_counts_eth[exchange_name] = {'positive': positive_count, 'negative': negative_count, 'ratio': pos_neg_ratio}

# Convert summary_counts to DataFrame for better visualization
summary_counts_df = pd.DataFrame.from_dict(summary_counts_eth, orient='index')
summary_counts_df.head()
# Out:
#                           positive  negative     ratio
# ETH_Binance_funding_rate      2901       362  0.889059
# ETH_BitMex_funding_rate       1526       310  0.831155
# ETH_Bybit_funding_rate        2270       335  0.871401
# ETH_Deribit_funding_rate      1458       717  0.670345
# ETH_Huobi_funding_rate        1606       396  0.802198

# %% [markdown]
# ### Longest periods of negative funding rates

# %%
# Step 3: Analyze negative funding rate periods
negative_periods_summary = {}

for column in merged_df.columns:
    exchange_name = column
    negative_periods = (merged_df[column] < 0).astype(int)
    negative_periods_diff = negative_periods.diff().fillna(0).astype(int)
    # Identifying the start and end of negative periods
    starts = negative_periods_diff[negative_periods_diff == 1].index
    ends = negative_periods_diff[negative_periods_diff == -1].index

    # Adjust if the series ends with a negative period
    if len(ends) < len(starts):
        ends = ends.append(pd.Index([negative_periods.index[-1]]))

    # Calculate lengths of negative periods
    periods_lengths = (ends - starts).days * 24
    

    longest_period = periods_lengths.max()
    mean_period = np.mean(periods_lengths.to_numpy())

    negative_periods_summary[exchange_name] = {
        'longest_period_hours': longest_period,
        'mean_period_hours': mean_period,
    }

# Convert to DataFrame for better visualization
negative_periods_summary_df = pd.DataFrame.from_dict(negative_periods_summary, orient='index')
negative_periods_summary_df.head(6)
# Out:
#                           longest_period_hours  mean_period_hours
# BTC_Binance_funding_rate                   192          15.728155
# BTC_BitMex_funding_rate                    168          16.440945
# BTC_Bybit_funding_rate                     168          17.806452
# BTC_Deribit_funding_rate                   552          34.360656
# BTC_Huobi_funding_rate                     168          10.227273
# BTC_OKX_funding_rate                       192          11.046575

# %%
# Step 3: Analyze negative funding rate periods
negative_periods_summary_eth = {}

for column in merged_df_eth.columns:
    exchange_name = column
    negative_periods = (merged_df_eth[column] < 0).astype(int)
    negative_periods_diff = negative_periods.diff().fillna(0).astype(int)
    # Identifying the start and end of negative periods
    starts = negative_periods_diff[negative_periods_diff == 1].index
    ends = negative_periods_diff[negative_periods_diff == -1].index

    # Adjust if the series ends with a negative period
    if len(ends) < len(starts):
        ends = ends.append(pd.Index([negative_periods.index[-1]]))

    # Calculate lengths of negative periods
    periods_lengths = (ends - starts).days * 24

    longest_period = periods_lengths.max()
    mean_period = np.mean(periods_lengths.to_numpy())

    negative_periods_summary_eth[exchange_name] = {
        'longest_period_hours': longest_period,
        'mean_period_hours': mean_period,
    }

# Convert to DataFrame for better visualization
negative_periods_summary_df_eth = pd.DataFrame.from_dict(negative_periods_summary_eth, orient='index')
negative_periods_summary_df_eth.head(6)
# Out:
#                           longest_period_hours  mean_period_hours
# ETH_Binance_funding_rate                   336          16.883721
# ETH_BitMex_funding_rate                    120          15.740260
# ETH_Bybit_funding_rate                     216          18.612245
# ETH_Deribit_funding_rate                   432          36.184615
# ETH_Huobi_funding_rate                     336          15.138462
# ETH_OKX_funding_rate                       576          18.847059

# %% [markdown]
# ### Check correlations between different exchanges

# %%
# Create the correlation matrix
correlation_matrix = merged_df.corr()

# Visualize the correlation matrix as a heatmap
fig = px.imshow(correlation_matrix,
                labels=dict(x="Exchange", y="Exchange", color="Correlation"),
                x=correlation_matrix.columns.str.replace('_funding_rate', ''),
                y=correlation_matrix.index.str.replace('_funding_rate', ''),
                color_continuous_scale='Viridis')

fig.update_layout(title='Correlation Matrix of BTC Funding Rates Across Exchanges',
                  xaxis_title='Exchange',
                  yaxis_title='Exchange')

fig.show()
# Out:
# <div>                            <div id="aa2327bf-96d1-48c9-a63e-8f2e2bcef08d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("aa2327bf-96d1-48c9-a63e-8f2e2bcef08d")) {                    Plotly.newPlot(                        "aa2327bf-96d1-48c9-a63e-8f2e2bcef08d",                        [{"coloraxis":"coloraxis","name":"0","x":["BTC_Binance","BTC_BitMex","BTC_Bybit","BTC_Deribit","BTC_Huobi","BTC_OKX"],"y":["BTC_Binance","BTC_BitMex","BTC_Bybit","BTC_Deribit","BTC_Huobi","BTC_OKX"],"z":[[1.0,0.7029684947935909,0.6920582009215461,0.6450254305436792,0.6098829742782507,0.7096167219178445],[0.7029684947935909,1.0,0.616770364377092,0.42164010954395614,0.45525977931134615,0.5035670835072776],[0.6920582009215461,0.616770364377092,1.0,0.4701838733865313,0.44696358091216715,0.5011459917644403],[0.6450254305436792,0.42164010954395614,0.4701838733865313,1.0,0.3110730870679154,0.41326345987231883],[0.6098829742782507,0.45525977931134615,0.44696358091216715,0.3110730870679154,1.0,0.5970074488201679],[0.7096167219178445,0.5035670835072776,0.5011459917644403,0.41326345987231883,0.5970074488201679,1.0]],"type":"heatmap","xaxis":"x","yaxis":"y","hovertemplate":"Exchange: %{x}\u003cbr\u003eExchange: %{y}\u003cbr\u003eCorrelation: %{z}\u003cextra\u003e\u003c\u002fextra\u003e"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorba ...

# %%
# Step 3: Create the correlation matrix
correlation_matrix = merged_df_eth.corr()

# Step 4: Visualize the correlation matrix as a heatmap
fig = px.imshow(correlation_matrix,
                labels=dict(x="Exchange", y="Exchange", color="Correlation"),
                x=correlation_matrix.columns.str.replace('_funding_rate', ''),
                y=correlation_matrix.index.str.replace('_funding_rate', ''),
                color_continuous_scale='Viridis')

fig.update_layout(title='Correlation Matrix of ETH Funding Rates Across Exchanges',
                  xaxis_title='Exchange',
                  yaxis_title='Exchange')

fig.show()
# Out:
# <div>                            <div id="ac7bd3f0-9d37-4e88-8ff2-69ef8a827662" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ac7bd3f0-9d37-4e88-8ff2-69ef8a827662")) {                    Plotly.newPlot(                        "ac7bd3f0-9d37-4e88-8ff2-69ef8a827662",                        [{"coloraxis":"coloraxis","name":"0","x":["ETH_Binance","ETH_BitMex","ETH_Bybit","ETH_Deribit","ETH_Huobi","ETH_OKX"],"y":["ETH_Binance","ETH_BitMex","ETH_Bybit","ETH_Deribit","ETH_Huobi","ETH_OKX"],"z":[[1.0,0.7702018151011292,0.7789476375047442,0.7171318181459052,0.7019149629177254,0.7301689458771853],[0.7702018151011292,1.0,0.7462409492019367,0.5682707210741824,0.5684997964392239,0.6089214838527122],[0.7789476375047442,0.7462409492019367,1.0,0.5127086098158603,0.582527438015335,0.6075230190393945],[0.7171318181459052,0.5682707210741824,0.5127086098158603,1.0,0.5184489586155584,0.5268232176334571],[0.7019149629177254,0.5684997964392239,0.582527438015335,0.5184489586155584,1.0,0.677987589175285],[0.7301689458771853,0.6089214838527122,0.6075230190393945,0.5268232176334571,0.677987589175285,1.0]],"type":"heatmap","xaxis":"x","yaxis":"y","hovertemplate":"Exchange: %{x}\u003cbr\u003eExchange: %{y}\u003cbr\u003eCorrelation: %{z}\u003cextra\u003e\u003c\u002fextra\u003e"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outli ...

# %% [markdown]
# ### Compare funding rates during bull and bear periods across exchanges

# %%
# Step 3: Define bull periods
bull_periods = [
    ("2021-10-01", "2021-12-01"),
    ("2023-11-01", "2024-01-15"),
    ("2024-02-10", "2024-03-12")
]

# Step 4: Calculate means and plot in a bar chart
mean_funding_rates = {}

for start_date, end_date in bull_periods:
    period_df = merged_df.loc[start_date:end_date]
    mean_funding_rates[start_date + " to " + end_date] = period_df.mean() * 3 * 365

mean_funding_rates_df = pd.DataFrame(mean_funding_rates)

fig = go.Figure()

for exchange in mean_funding_rates_df.index:
    fig.add_trace(go.Bar(
        x=mean_funding_rates_df.columns,
        y=mean_funding_rates_df.loc[exchange],
        name=exchange,
        text=mean_funding_rates_df.loc[exchange] * 100,  # Multiply by 100 to convert to percentage
        texttemplate='%{text:.2f}%',  # Format as percentage with two decimal places
        textposition='inside'  # Position text outside the bars
    ))

fig.update_layout(
    title='Annualized Mean BTC Funding Rates During Bull Runs',
    xaxis_title='Bull Period',
    yaxis_title='Mean Funding Rate',
    barmode='group',
    yaxis=dict(
        tickformat=".2f"
    ),
)

fig.show()
# Out:
# <div>                            <div id="779afcd5-ea34-4e31-94b2-7240356f0a41" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("779afcd5-ea34-4e31-94b2-7240356f0a41")) {                    Plotly.newPlot(                        "779afcd5-ea34-4e31-94b2-7240356f0a41",                        [{"name":"BTC_Binance_funding_rate","text":[25.11994905241935,16.334885822368424,33.000579609375],"textposition":"inside","texttemplate":"%{text:.2f}%","x":["2021-10-01 to 2021-12-01","2023-11-01 to 2024-01-15","2024-02-10 to 2024-03-12"],"y":[0.2511994905241935,0.16334885822368425,0.33000579609375],"type":"bar"},{"name":"BTC_BitMex_funding_rate","text":[11.206329545454548,19.62571381578947,39.7125703125],"textposition":"inside","texttemplate":"%{text:.2f}%","x":["2021-10-01 to 2021-12-01","2023-11-01 to 2024-01-15","2024-02-10 to 2024-03-12"],"y":[0.11206329545454548,0.19625713815789472,0.397125703125],"type":"bar"},{"name":"BTC_Bybit_funding_rate","text":[35.997003508064516,19.069626710526318,32.3996128125],"textposition":"inside","texttemplate":"%{text:.2f}%","x":["2021-10-01 to 2021-12-01","2023-11-01 to 2024-01-15","2024-02-10 to 2024-03-12"],"y":[0.3599700350806452,0.1906962671052632,0.323996128125],"type":"bar"},{"name":"BTC_Deribit_funding_rate","text":[13.404355860284776,15.323592727466098,25.21686478515611],"textposition":"inside","texttemplate":"%{text:.2f}%","x":["2021-10-01 to 2021-12-01","2023-11-01 to 2024-01-15","2024-02-10 to 2024-03-12"],"y":[0.13404355860284775,0.15323592727466098,0.25216864785156107],"type":"bar"},{"name":"BTC_Huobi_funding_rate","text":[12.854907339080532,22.193092687188322,30.91354315541596],"textposition":"inside","texttemplate":"%{text:.2f}%","x":["2021-10-01 to 2021-12-01","2023-11-01 to 2024-01-15","2024-02-10 to 2024-03-12"],"y":[0.12854907339080532,0.22193092687188323,0.3091354315541596],"type":"bar"},{"name":"BTC_OKX_funding_rate","text":[22.820294516129017,16.600250717466185,38.60212452564921],"textposition":"inside","texttemplate":"%{text:.2f}%","x":["2021-10-01 to 2021-12-01","2023-11-01 to 2024-01-15","2024-02-10 to 2024-03-12"],"y":[0.22820294516129017,0.16600250717466183,0.38602124525649206],"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.88 ...

# %%
# Step 4: Calculate means and plot in a bar chart
mean_funding_rates_eth = {}

for start_date, end_date in bull_periods:
    period_df = merged_df_eth.loc[start_date:end_date]
    mean_funding_rates[start_date + " to " + end_date] = period_df.mean() * 3 * 365

mean_funding_rates_df = pd.DataFrame(mean_funding_rates)

fig = go.Figure()

for exchange in mean_funding_rates_df.index:
    fig.add_trace(go.Bar(
        x=mean_funding_rates_df.columns,
        y=mean_funding_rates_df.loc[exchange],
        name=exchange,
        text=mean_funding_rates_df.loc[exchange] * 100,  # Multiply by 100 to convert to percentage
        texttemplate='%{text:.2f}%',  # Format as percentage with two decimal places
        textposition='inside'  # Position text outside the bars
    ))

fig.update_layout(
    title='Annualized Mean ETH Funding Rates During Bull Runs',
    xaxis_title='Bull Period',
    yaxis_title='Mean Funding Rate',
    barmode='group',
    yaxis=dict(
        tickformat=".2f"
    ),
)

fig.show()
# Out:
# <div>                            <div id="9dba5331-4bbe-40d3-b6d9-5e5721312e9c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9dba5331-4bbe-40d3-b6d9-5e5721312e9c")) {                    Plotly.newPlot(                        "9dba5331-4bbe-40d3-b6d9-5e5721312e9c",                        [{"name":"ETH_Binance_funding_rate","text":[22.675657379032252,17.974770789473684,31.810314609375006],"textposition":"inside","texttemplate":"%{text:.2f}%","x":["2021-10-01 to 2021-12-01","2023-11-01 to 2024-01-15","2024-02-10 to 2024-03-12"],"y":[0.22675657379032252,0.17974770789473685,0.31810314609375007],"type":"bar"},{"name":"ETH_BitMex_funding_rate","text":[10.950000000000003,20.344667763157894,46.40746875],"textposition":"inside","texttemplate":"%{text:.2f}%","x":["2021-10-01 to 2021-12-01","2023-11-01 to 2024-01-15","2024-02-10 to 2024-03-12"],"y":[0.10950000000000003,0.20344667763157892,0.4640746875],"type":"bar"},{"name":"ETH_Bybit_funding_rate","text":[25.493397036290315,18.83337325657895,27.488837226562502],"textposition":"inside","texttemplate":"%{text:.2f}%","x":["2021-10-01 to 2021-12-01","2023-11-01 to 2024-01-15","2024-02-10 to 2024-03-12"],"y":[0.25493397036290316,0.18833373256578947,0.274888372265625],"type":"bar"},{"name":"ETH_Deribit_funding_rate","text":[8.857108616987153,23.92061241649999,26.913010582384594],"textposition":"inside","texttemplate":"%{text:.2f}%","x":["2021-10-01 to 2021-12-01","2023-11-01 to 2024-01-15","2024-02-10 to 2024-03-12"],"y":[0.08857108616987153,0.2392061241649999,0.26913010582384594],"type":"bar"},{"name":"ETH_Huobi_funding_rate","text":[13.670151291442673,23.267034266182534,40.967540160455904],"textposition":"inside","texttemplate":"%{text:.2f}%","x":["2021-10-01 to 2021-12-01","2023-11-01 to 2024-01-15","2024-02-10 to 2024-03-12"],"y":[0.13670151291442673,0.23267034266182535,0.409675401604559],"type":"bar"},{"name":"ETH_OKX_funding_rate","text":[19.85831068548386,17.679597361635413,34.52160788695052],"textposition":"inside","texttemplate":"%{text:.2f}%","x":["2021-10-01 to 2021-12-01","2023-11-01 to 2024-01-15","2024-02-10 to 2024-03-12"],"y":[0.1985831068548386,0.17679597361635413,0.34521607886950517],"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f ...

# %%
# Step 3: Define bear periods
bear_periods = [
    ("2021-12-15", "2022-12-30"),
    ("2023-08-01", "2023-10-15"),
    ("2024-03-20", "2024-05-05")
]

# Step 4: Calculate means and plot in a bar chart
mean_funding_rates = {}

for start_date, end_date in bear_periods:
    period_df = merged_df.loc[start_date:end_date]
    mean_funding_rates[start_date + " to " + end_date] = period_df.mean() * 3 * 365

mean_funding_rates_df = pd.DataFrame(mean_funding_rates)

fig = go.Figure()

for exchange in mean_funding_rates_df.index:
    fig.add_trace(go.Bar(
        x=mean_funding_rates_df.columns,
        y=mean_funding_rates_df.loc[exchange],
        name=exchange,
        text=mean_funding_rates_df.loc[exchange] * 100,  # Multiply by 100 to convert to percentage
        texttemplate='%{text:.2f}%',  # Format as percentage with two decimal places
        textposition='auto'  # Position text outside the bars
    ))

fig.update_layout(
    title='Annualized Mean BTC Funding Rates During Bear Periods',
    xaxis_title='Bear Period',
    yaxis_title='Mean Funding Rate',
    barmode='group',
    yaxis=dict(
        tickformat=".2f"
    ),
)

fig.show()
# Out:
# <div>                            <div id="44699bc6-484a-4352-8e5a-fdfda1c8b38a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("44699bc6-484a-4352-8e5a-fdfda1c8b38a")) {                    Plotly.newPlot(                        "44699bc6-484a-4352-8e5a-fdfda1c8b38a",                        [{"name":"BTC_Binance_funding_rate","text":[4.534569596456693,3.569840476973684,13.461712553191488],"textposition":"auto","texttemplate":"%{text:.2f}%","x":["2021-12-15 to 2022-12-30","2023-08-01 to 2023-10-15","2024-03-20 to 2024-05-05"],"y":[0.04534569596456693,0.03569840476973684,0.13461712553191488],"type":"bar"},{"name":"BTC_BitMex_funding_rate","text":[3.105948818897639,3.923990131578947,20.33088829787234],"textposition":"auto","texttemplate":"%{text:.2f}%","x":["2021-12-15 to 2022-12-30","2023-08-01 to 2023-10-15","2024-03-20 to 2024-05-05"],"y":[0.03105948818897639,0.03923990131578947,0.20330888297872343],"type":"bar"},{"name":"BTC_Bybit_funding_rate","text":[3.10214002952756,5.173518404605263,12.453895132978724],"textposition":"auto","texttemplate":"%{text:.2f}%","x":["2021-12-15 to 2022-12-30","2023-08-01 to 2023-10-15","2024-03-20 to 2024-05-05"],"y":[0.031021400295275597,0.05173518404605263,0.12453895132978725],"type":"bar"},{"name":"BTC_Deribit_funding_rate","text":[-1.1234505136052224,6.111692773012044,7.857426087927146],"textposition":"auto","texttemplate":"%{text:.2f}%","x":["2021-12-15 to 2022-12-30","2023-08-01 to 2023-10-15","2024-03-20 to 2024-05-05"],"y":[-0.011234505136052224,0.061116927730120445,0.07857426087927145],"type":"bar"},{"name":"BTC_Huobi_funding_rate","text":[5.801973574277088,2.638082065775259,10.448685685313626],"textposition":"auto","texttemplate":"%{text:.2f}%","x":["2021-12-15 to 2022-12-30","2023-08-01 to 2023-10-15","2024-03-20 to 2024-05-05"],"y":[0.05801973574277088,0.026380820657752588,0.10448685685313626],"type":"bar"},{"name":"BTC_OKX_funding_rate","text":[1.5330304036899551,1.9958546307864387,10.829110231184517],"textposition":"auto","texttemplate":"%{text:.2f}%","x":["2021-12-15 to 2022-12-30","2023-08-01 to 2023-10-15","2024-03-20 to 2024-05-05"],"y":[0.015330304036899552,0.019958546307864387,0.10829110231184516],"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.77777777777777 ...

# %%
# Step 4: Calculate means and plot in a bar chart
mean_funding_rates_eth = {}

for start_date, end_date in bear_periods:
    period_df = merged_df_eth.loc[start_date:end_date]
    mean_funding_rates_eth[start_date + " to " + end_date] = period_df.mean() * 3 * 365

mean_funding_rates_df_eth = pd.DataFrame(mean_funding_rates_eth)

fig = go.Figure()

for exchange in mean_funding_rates_df_eth.index:
    fig.add_trace(go.Bar(
        x=mean_funding_rates_df_eth.columns,
        y=mean_funding_rates_df_eth.loc[exchange],
        name=exchange,
        text=mean_funding_rates_df_eth.loc[exchange] * 100,  # Multiply by 100 to convert to percentage
        texttemplate='%{text:.2f}%',  # Format as percentage with two decimal places
        textposition='auto'  # Position text outside the bars
    ))

fig.update_layout(
    title='Annualized Mean ETH Funding Rates During Bear Periods',
    xaxis_title='Bear Period',
    yaxis_title='Mean Funding Rate',
    barmode='group',
    yaxis=dict(
        tickformat=".2f"
    ),
)

fig.show()
# Out:
# <div>                            <div id="5843d045-31f0-496d-b284-79e5bca4f169" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5843d045-31f0-496d-b284-79e5bca4f169")) {                    Plotly.newPlot(                        "5843d045-31f0-496d-b284-79e5bca4f169",                        [{"name":"ETH_Binance_funding_rate","text":[1.2421709219160109,3.6884066447368427,14.355385930851064],"textposition":"auto","texttemplate":"%{text:.2f}%","x":["2021-12-15 to 2022-12-30","2023-08-01 to 2023-10-15","2024-03-20 to 2024-05-05"],"y":[0.012421709219160108,0.03688406644736843,0.14355385930851064],"type":"bar"},{"name":"ETH_BitMex_funding_rate","text":[-0.7118937007874004,3.1884671052631584,24.475579787234032],"textposition":"auto","texttemplate":"%{text:.2f}%","x":["2021-12-15 to 2022-12-30","2023-08-01 to 2023-10-15","2024-03-20 to 2024-05-05"],"y":[-0.007118937007874005,0.03188467105263158,0.24475579787234034],"type":"bar"},{"name":"ETH_Bybit_funding_rate","text":[2.2399230905511813,3.4995515625,13.50563680851064],"textposition":"auto","texttemplate":"%{text:.2f}%","x":["2021-12-15 to 2022-12-30","2023-08-01 to 2023-10-15","2024-03-20 to 2024-05-05"],"y":[0.022399230905511814,0.034995515625,0.1350563680851064],"type":"bar"},{"name":"ETH_Deribit_funding_rate","text":[-4.910020362537877,4.520360846560432,-2.242924290986672],"textposition":"auto","texttemplate":"%{text:.2f}%","x":["2021-12-15 to 2022-12-30","2023-08-01 to 2023-10-15","2024-03-20 to 2024-05-05"],"y":[-0.04910020362537877,0.04520360846560432,-0.02242924290986672],"type":"bar"},{"name":"ETH_Huobi_funding_rate","text":[0.3447600399674556,6.641137627427243,20.220740071587546],"textposition":"auto","texttemplate":"%{text:.2f}%","x":["2021-12-15 to 2022-12-30","2023-08-01 to 2023-10-15","2024-03-20 to 2024-05-05"],"y":[0.003447600399674556,0.06641137627427243,0.20220740071587545],"type":"bar"},{"name":"ETH_OKX_funding_rate","text":[-4.2472629811665765,2.444808515218397,12.827804085309943],"textposition":"auto","texttemplate":"%{text:.2f}%","x":["2021-12-15 to 2022-12-30","2023-08-01 to 2023-10-15","2024-03-20 to 2024-05-05"],"y":[-0.04247262981166577,0.024448085152183968,0.12827804085309943],"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.777777777777777 ...
